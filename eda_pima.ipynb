# %% [markdown]
# <a href="https://colab.research.google.com/github/h1tenbafna/DA_Lab/blob/main/eda_pima.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploratory Data Analysis with Python

# %% [markdown]
# Importing the required Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set(color_codes=True)
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Datasets/
# Out:
# /content/drive/MyDrive/Datasets

# %% [markdown]
# Reading the dataest

# %%
diabetes_data = pd.read_csv('pima-indians-diabetes.csv')

# %% [markdown]
# The first thing we will check is the size of our dataset. We can use `info()` to get the number of entries of each column.

# %%
diabetes_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Preg    768 non-null    int64
#  1   Plas    768 non-null    int64
#  2   Pres    768 non-null    int64
#  3   skin    768 non-null    int64
#  4   test    768 non-null    int64
#  5   mass    768 non-null    float64
#  6   pedi    768 non-null    float64
#  7   age     768 non-null    int64
#  8   class   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
diabetes_data.head(10)
# Out:
#    Preg  Plas  Pres  skin  test  mass   pedi  age  class
# 0     6   148    72    35     0  33.6  0.627   50      1
# 1     1    85    66    29     0  26.6  0.351   31      0
# 2     8   183    64     0     0  23.3  0.672   32      1
# 3     1    89    66    23    94  28.1  0.167   21      0
# 4     0   137    40    35   168  43.1  2.288   33      1
# 5     5   116    74     0     0  25.6  0.201   30      0
# 6     3    78    50    32    88  31.0  0.248   26      1
# 7    10   115     0     0     0  35.3  0.134   29      0
# 8     2   197    70    45   543  30.5  0.158   53      1
# 9     8   125    96     0     0   0.0  0.232   54      1

# %%
diabetes_data.value_counts('class')
# Out:
# class
# 0    500
# 1    268
# dtype: int64

# %% [markdown]
# In this dataset, 268 women are diabetic and 500 are non-diabetic

# %%
diabetes_data.describe(
)
# Out:
#              Preg        Plas        Pres        skin        test        mass  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#              pedi         age       class
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# ...

# %%
diabetes_data.describe().T
# Out:
#        count        mean         std     min       25%       50%        75%  \
# Preg   768.0    3.845052    3.369578   0.000   1.00000    3.0000    6.00000
# Plas   768.0  120.894531   31.972618   0.000  99.00000  117.0000  140.25000
# Pres   768.0   69.105469   19.355807   0.000  62.00000   72.0000   80.00000
# skin   768.0   20.536458   15.952218   0.000   0.00000   23.0000   32.00000
# test   768.0   79.799479  115.244002   0.000   0.00000   30.5000  127.25000
# mass   768.0   31.992578    7.884160   0.000  27.30000   32.0000   36.60000
# pedi   768.0    0.471876    0.331329   0.078   0.24375    0.3725    0.62625
# age    768.0   33.240885   11.760232  21.000  24.00000   29.0000   41.00000
# class  768.0    0.348958    0.476951   0.000   0.00000    0.0000    1.00000
#
#           max
# Preg    17.00
# Plas   199.00
# Pres   122.00
# skin    99.00
# test   846.00
# mass    67.10
# pedi     2.42
# age     81.00
# class    1.00

# %%
diabetes_data.max()
# Out:
# Preg      17.00
# Plas     199.00
# Pres     122.00
# skin      99.00
# test     846.00
# mass      67.10
# pedi       2.42
# age       81.00
# class      1.00
# dtype: float64

# %%
diabetes_data.min()
# Out:
# Preg      0.000
# Plas      0.000
# Pres      0.000
# skin      0.000
# test      0.000
# mass      0.000
# pedi      0.078
# age      21.000
# class     0.000
# dtype: float64

# %%
diabetes_data.mean()
# Out:
# Preg       3.845052
# Plas     120.894531
# Pres      69.105469
# skin      20.536458
# test      79.799479
# mass      31.992578
# pedi       0.471876
# age       33.240885
# class      0.348958
# dtype: float64

# %%
diabetes_data.shape
# Out:
# (768, 9)

# %%
diabetes_data.isnull().values.any()
# Out:
# False

# %%
diabetes_data.isnull().sum()
# Out:
# Preg     0
# Plas     0
# Pres     0
# skin     0
# test     0
# mass     0
# pedi     0
# age      0
# class    0
# dtype: int64

# %% [markdown]
# It shows there are no null values but 0 is not considered in Null here but we know that 0 can also be the missing value, so we replace 0 by Nan

# %% [markdown]
# Replacing 0 to NaN

# %%
data = diabetes_data[['Plas','Pres','skin','test','mass','pedi']]=diabetes_data[['Plas','Pres','skin','test','mass','pedi']].replace(0,np.nan)
data.head(15)
# Out:
#      Plas  Pres  skin   test  mass   pedi
# 0   148.0  72.0  35.0    NaN  33.6  0.627
# 1    85.0  66.0  29.0    NaN  26.6  0.351
# 2   183.0  64.0   NaN    NaN  23.3  0.672
# 3    89.0  66.0  23.0   94.0  28.1  0.167
# 4   137.0  40.0  35.0  168.0  43.1  2.288
# 5   116.0  74.0   NaN    NaN  25.6  0.201
# 6    78.0  50.0  32.0   88.0  31.0  0.248
# 7   115.0   NaN   NaN    NaN  35.3  0.134
# 8   197.0  70.0  45.0  543.0  30.5  0.158
# 9   125.0  96.0   NaN    NaN   NaN  0.232
# 10  110.0  92.0   NaN    NaN  37.6  0.191
# 11  168.0  74.0   NaN    NaN  38.0  0.537
# 12  139.0  80.0   NaN    NaN  27.1  1.441
# 13  189.0  60.0  23.0  846.0  30.1  0.398
# 14  166.0  72.0  19.0  175.0  25.8  0.587

# %%
data.isnull().sum()[['Plas','Pres','skin','test','mass','pedi']]
# Out:
# Plas      5
# Pres     35
# skin    227
# test    374
# mass     11
# pedi      0
# dtype: int64

# %% [markdown]
# So, we replace 0 by nan (null) value, then we calculate the sum of null values in our dataset. We find that there are 5 null in Plas, 35 in Pres & so on.

# %% [markdown]
# Now replacing the NaN to median

# %% [markdown]
# Since the null values are very less in number, so we replace them with median.

# %%
diabetes_data['Plas'].fillna(diabetes_data['Plas'].median(),inplace=True)
diabetes_data['Pres'].fillna(diabetes_data['Pres'].median(),inplace=True)
diabetes_data['skin'].fillna(diabetes_data['skin'].median(),inplace=True)
diabetes_data['test'].fillna(diabetes_data['test'].median(),inplace=True)
diabetes_data['mass'].fillna(diabetes_data['mass'].median(),inplace=True)

diabetes_data.head()
# Out:
#    Preg   Plas  Pres  skin   test  mass   pedi  age  class
# 0     6  148.0  72.0  35.0  125.0  33.6  0.627   50      1
# 1     1   85.0  66.0  29.0  125.0  26.6  0.351   31      0
# 2     8  183.0  64.0  29.0  125.0  23.3  0.672   32      1
# 3     1   89.0  66.0  23.0   94.0  28.1  0.167   21      0
# 4     0  137.0  40.0  35.0  168.0  43.1  2.288   33      1

# %% [markdown]
# Finding the max_age in the dataset

# %%
maxvalues = diabetes_data.max()
maxvalues
# Out:
# Preg      17.00
# Plas     199.00
# Pres     122.00
# skin      99.00
# test     846.00
# mass      67.10
# pedi       2.42
# age       81.00
# class      1.00
# dtype: float64

# %% [markdown]
# Encoding the age

# %%
# Dividing the age into buckets

def age(df):
    df.loc[(df['age'] > 20) & (df['age'] <= 39), 'age'] = 1
    df.loc[(df['age'] >= 40) & (df['age'] <= 59), 'age'] = 2
    df.loc[(df['age'] >= 60) & (df['age'] <= 81), 'age'] = 3       
    return df
age(diabetes_data)
# Out:
#      Preg   Plas  Pres  skin   test  mass   pedi  age  class
# 0       6  148.0  72.0  35.0  125.0  33.6  0.627    2      1
# 1       1   85.0  66.0  29.0  125.0  26.6  0.351    1      0
# 2       8  183.0  64.0  29.0  125.0  23.3  0.672    1      1
# 3       1   89.0  66.0  23.0   94.0  28.1  0.167    1      0
# 4       0  137.0  40.0  35.0  168.0  43.1  2.288    1      1
# ..    ...    ...   ...   ...    ...   ...    ...  ...    ...
# 763    10  101.0  76.0  48.0  180.0  32.9  0.171    3      0
# 764     2  122.0  70.0  27.0  125.0  36.8  0.340    1      0
# 765     5  121.0  72.0  23.0  112.0  26.2  0.245    1      0
# 766     1  126.0  60.0  29.0  125.0  30.1  0.349    2      1
# 767     1   93.0  70.0  31.0  125.0  30.4  0.315    1      0
#
# [768 rows x 9 columns]

# %%
# countplot (shows the count of the class)
sns.countplot(x="class", data=diabetes_data)

# %% [markdown]
# Since the problem statement requires binary classification, i.e diabetic or not diabetic. So countplot shows the count of people with diabetes and not. So from the plot we can see that 268 people are diabetic

# %%
sns.countplot(x="age", data=diabetes_data)

# %% [markdown]
# Age encoded in buckets of 3

# %%
# Histogram
diabetes_data.hist(bins=50, figsize=(20, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fee05059890>,
# ...
#       dtype=object)

# %% [markdown]
# The above figure consists of histogram plots of all the columns in the dataset. It shows the distribution of the values of every attribute. Y axis gives the count.

# %%
diabetes_data.plot(kind='density', subplots=True, layout=(3,3), figsize=(20, 15), sharex=False)
plt.show()

# %% [markdown]
# This plot shows the distribution of all the attributes

# %%
# scatter plot (which shows the relationship between the attributes)

sns.pairplot(diabetes_data, hue="class")

# %% [markdown]
# Diabetic women tend to show larger values of age, mass, test, skin thickness, blood pressure, and pregnancies.
# The feature that it is possible to see 2 distinct groups (diabetic and non diabetic) is Plas.

# %%
#Box and Whisker plot to visualize the distribution of all atributes
diabetes_data.plot(kind= 'box' , subplots=True, layout=(3,3), sharex=False, sharey=False, figsize=(20,15))
# Out:
# Preg        AxesSubplot(0.125,0.657941;0.227941x0.222059)
# Plas     AxesSubplot(0.398529,0.657941;0.227941x0.222059)
# Pres     AxesSubplot(0.672059,0.657941;0.227941x0.222059)
# skin        AxesSubplot(0.125,0.391471;0.227941x0.222059)
# test     AxesSubplot(0.398529,0.391471;0.227941x0.222059)
# mass     AxesSubplot(0.672059,0.391471;0.227941x0.222059)
# pedi           AxesSubplot(0.125,0.125;0.227941x0.222059)
# age         AxesSubplot(0.398529,0.125;0.227941x0.222059)
# class       AxesSubplot(0.672059,0.125;0.227941x0.222059)
# dtype: object

# %%
sns.lmplot(x='pedi', y= 'mass', data=diabetes_data)

# %%
# correlation matrix

cor=diabetes_data.corr()
cor
# Out:
#            Preg      Plas      Pres      skin      test      mass      pedi  \
# Preg   1.000000  0.128213  0.208615  0.081770  0.025047  0.021559 -0.033523
# Plas   0.128213  1.000000  0.218937  0.192615  0.419451  0.231049  0.137327
# Pres   0.208615  0.218937  1.000000  0.191892  0.045363  0.281257 -0.002378
# skin   0.081770  0.192615  0.191892  1.000000  0.155610  0.543205  0.102188
# test   0.025047  0.419451  0.045363  0.155610  1.000000  0.180241  0.126503
# mass   0.021559  0.231049  0.281257  0.543205  0.180241  1.000000  0.153438
# pedi  -0.033523  0.137327 -0.002378  0.102188  0.126503  0.153438  1.000000
# age    0.433042  0.203446  0.262476  0.087243  0.066553  0.011290 -0.013611
# class  0.221898  0.492782  0.165723  0.214873  0.203790  0.312038  0.173844
#
#             age     class
# Preg   0.433042  0.221898
# Plas   0.203446  0.492782
# Pres   0.262476  0.165723
# skin   0.087243  0.214873
# test   0.066553  0.203790
# mass   0.011290  0.312038
# ...

# %% [markdown]
# There are no strong correlation between the features. The 'strongest' ones are the following:
#         skin x mass (0.54)

# %%
sns.heatmap(cor, annot=True)
